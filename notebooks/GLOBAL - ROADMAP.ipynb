# %% [markdown]
# ROADMAP GLOBAL

# %%
# Roadmap global — Data Engineering

## 🎯 Objectif

Construire une maîtrise complète du **Data Engineering moderne**, de la collecte des données jusqu'au traitement distribué, au cloud, au streaming et à la mise en production.

---

## 1. Python for Data

* [x] Python avancé
* [x] Environnement virtuel
* [x] NumPy
* [x] Pandas
* [x] Matplotlib / Seaborn
* [x] Manipulation CSV / JSON
* [x] Gestion des fichiers
* [x] Exceptions / logging
* [x] SQLAlchemy / psycopg

---

## 2. SQL & PostgreSQL

### SQL avancé

* [x] SELECT / WHERE / ORDER BY
* [x] GROUP BY / HAVING
* [x] JOIN
* [x] Subqueries
* [x] CTE
* [x] Window Functions
* [x] CASE / COALESCE
* [x] Agrégations
* [x] EXISTS / IN
* [ ] SQL avancé supplémentaire

### PostgreSQL

* [x] Installation / configuration
* [x] Users / roles
* [x] Schemas
* [x] Constraints
* [x] Indexes
* [x] Transactions
* [x] PostgreSQL administration de base

### PostgreSQL Performance

* [x] EXPLAIN
* [x] Seq Scan
* [x] Index Scan
* [x] Bitmap Scan
* [x] EXPLAIN ANALYZE
* [x] Buffers
* [x] Selectivity
* [x] pg_stats
* [x] ANALYZE
* [ ] Indexes avancés
* [ ] Query optimization
* [ ] JOIN plans
* [ ] Aggregations & memory
* [ ] Partitioning
* [ ] VACUUM / bloat
* [ ] Monitoring PostgreSQL

---

## 3. Data Modeling & Data Warehouse

* [x] OLTP vs OLAP
* [x] Fact tables
* [x] Dimension tables
* [x] Star Schema
* [x] Snowflake Schema
* [x] Primary / Foreign Keys
* [x] Slowly Changing Dimensions
* [x] SCD Type 1
* [x] SCD Type 2
* [x] Data Warehouse PostgreSQL
* [x] Projet Olist

---

## 4. ETL / ELT

* [x] ETL concepts
* [x] ELT concepts
* [x] Raw / Staging / Processed
* [x] Data transformations
* [x] Incremental loading
* [x] Full loading
* [x] Idempotence
* [x] Data pipelines
* [ ] Advanced ETL patterns

---

## 5. dbt

* [x] Installation
* [x] Sources
* [x] Staging models
* [x] Intermediate models
* [x] Mart models
* [x] Tests
* [x] Documentation
* [x] Incremental models
* [x] Snapshots
* [x] SCD Type 2
* [x] Dependencies
* [x] dbt run
* [x] dbt test
* [ ] Advanced dbt

---

## 6. Airflow — Orchestration

* [x] Installation
* [x] DAG
* [x] Tasks
* [x] Dependencies
* [x] Scheduling
* [x] Operators
* [x] PostgreSQL integration
* [x] dbt integration
* [x] Pipeline execution
* [x] Failure handling
* [x] Retry
* [ ] Advanced Airflow
* [ ] Sensors
* [ ] Dynamic Task Mapping
* [ ] TaskFlow API

---

## 7. Data Quality

* [x] Data validation
* [x] NULL checks
* [x] Duplicate detection
* [x] Referential integrity
* [x] Row-count validation
* [x] Volume anomaly detection
* [x] dbt tests
* [x] Pipeline quality checks
* [ ] Great Expectations / Soda
* [ ] Advanced data contracts

---

## 8. Observability & Monitoring

* [x] Pipeline metrics
* [x] Pipeline duration
* [x] Pipeline status
* [x] PostgreSQL metrics
* [x] Prometheus
* [x] Grafana
* [x] PostgreSQL Exporter
* [x] Custom Pipeline Exporter
* [x] Dashboard
* [x] Volume anomaly monitoring
* [ ] Advanced alerting
* [ ] SLIs / SLOs
* [ ] Incident analysis

---

# 9. Apache Spark / PySpark ⭐ NEXT MAJOR MODULE

## Spark Fundamentals

* [ ] Apache Spark architecture
* [ ] Driver
* [ ] Executors
* [ ] Cluster Manager
* [ ] Local Mode
* [ ] SparkSession

## PySpark

* [ ] DataFrame
* [ ] Schema
* [ ] Read CSV
* [ ] Read Parquet
* [ ] Write Parquet
* [ ] select
* [ ] filter
* [ ] withColumn
* [ ] groupBy
* [ ] agg
* [ ] orderBy
* [ ] distinct

## Spark SQL

* [ ] SQL queries
* [ ] Temporary Views
* [ ] SQL + DataFrame API
* [ ] Complex transformations

## Joins

* [ ] Inner Join
* [ ] Left Join
* [ ] Right Join
* [ ] Full Join
* [ ] Broadcast Join
* [ ] Join optimization

## Spark Execution

* [ ] Transformations
* [ ] Actions
* [ ] Lazy Evaluation
* [ ] DAG
* [ ] Stages
* [ ] Tasks
* [ ] Shuffle
* [ ] Partitions

## Performance

* [ ] Partitioning
* [ ] Repartition
* [ ] Coalesce
* [ ] Cache
* [ ] Persist
* [ ] Broadcast
* [ ] Shuffle optimization
* [ ] Spark UI
* [ ] Explain plans
* [ ] Adaptive Query Execution

## Practical Project

* [ ] Olist CSV → PySpark
* [ ] Transformations
* [ ] Cleaning
* [ ] Joins
* [ ] Aggregations
* [ ] Parquet
* [ ] Spark optimization
* [ ] Integration PostgreSQL

> 💡 Avec **4 Go RAM + 256 Go SSD**, on travaillera en **Spark Local Mode** et principalement avec le dataset Olist.

---

# 10. Cloud Data Engineering

### Cloud fundamentals

* [ ] Cloud concepts
* [ ] Object Storage
* [ ] Compute
* [ ] Networking
* [ ] IAM
* [ ] Secrets
* [ ] Monitoring

### AWS / Azure / GCP

Choisir principalement **un cloud**.

* [ ] Object Storage
* [ ] Managed PostgreSQL
* [ ] Compute
* [ ] Data Warehouse
* [ ] IAM
* [ ] Monitoring

### Architecture

* [ ] Data Lake
* [ ] Data Warehouse
* [ ] Lakehouse
* [ ] Medallion Architecture
* [ ] Bronze
* [ ] Silver
* [ ] Gold

---

# 11. Kafka / Streaming

## Kafka

* [ ] Kafka architecture
* [ ] Broker
* [ ] Topic
* [ ] Partition
* [ ] Producer
* [ ] Consumer
* [ ] Consumer Group
* [ ] Offset
* [ ] Replication

## Streaming

* [ ] Event-driven architecture
* [ ] Real-time ingestion
* [ ] Kafka + Python
* [ ] Kafka + Spark
* [ ] Structured Streaming
* [ ] Windowing
* [ ] Checkpointing
* [ ] Exactly-once concepts

---

# 12. CI/CD Data Engineering

* [x] Git
* [x] GitHub
* [x] GitHub Actions
* [x] Docker
* [ ] CI pipeline Data
* [ ] Tests automatisés
* [ ] dbt CI
* [ ] Airflow CI/CD
* [ ] Docker image CI
* [ ] Security scanning
* [ ] Secrets management
* [ ] Deployment automatisé

---

# 13. Data Engineering Security

* [ ] Secrets management
* [ ] IAM
* [ ] Database permissions
* [ ] Least privilege
* [ ] Encryption
* [ ] Network security
* [ ] Credential rotation
* [ ] Data masking
* [ ] Audit logging
* [ ] Security in CI/CD

---

# 14. Advanced Data Engineering

* [ ] Data contracts
* [ ] Schema evolution
* [ ] CDC — Change Data Capture
* [ ] Debezium
* [ ] Lakehouse
* [ ] Delta Lake / Iceberg
* [ ] Data lineage
* [ ] Metadata management
* [ ] Data governance
* [ ] Cost optimization
* [ ] Distributed systems concepts

---

# 15. Projet final 🚀

Construire une plateforme Data Engineering complète.

```text
                    ┌──────────────┐
                    │   Sources    │
                    │ CSV / API /  │
                    │ PostgreSQL   │
                    └──────┬───────┘
                           │
                           ▼
                    ┌──────────────┐
                    │     RAW      │
                    │    Bronze    │
                    └──────┬───────┘
                           │
                    Airflow│
                           ▼
                    ┌──────────────┐
                    │    dbt /     │
                    │   PySpark    │
                    └──────┬───────┘
                           │
                           ▼
                    ┌──────────────┐
                    │   STAGING    │
                    │    Silver    │
                    └──────┬───────┘
                           │
                           ▼
                    ┌──────────────┐
                    │     MART     │
                    │     Gold     │
                    └──────┬───────┘
                           │
              ┌────────────┴────────────┐
              ▼                         ▼
       ┌──────────────┐          ┌──────────────┐
       │   Power BI   │          │   Analytics  │
       └──────────────┘          └──────────────┘

        Prometheus + Grafana
        Data Quality + Alerts
```

### Le projet devra intégrer

* [ ] Data ingestion
* [ ] PostgreSQL
* [ ] Data Warehouse
* [ ] dbt
* [ ] PySpark
* [ ] Airflow
* [ ] Data Quality
* [ ] Incremental processing
* [ ] Monitoring
* [ ] Prometheus
* [ ] Grafana
* [ ] Docker
* [ ] CI/CD
* [ ] Cloud
* [ ] Documentation
* [ ] Tests
* [ ] Security
* [ ] Power BI

---

# 🗺️ Ordre d'apprentissage recommandé

```text
Python
   ↓
SQL
   ↓
PostgreSQL
   ↓
Data Modeling
   ↓
Data Warehouse
   ↓
ETL / ELT
   ↓
dbt
   ↓
Airflow
   ↓
Data Quality
   ↓
Observability
   ↓
PostgreSQL Performance
   ↓
🔥 PySpark / Spark
   ↓
Cloud
   ↓
Kafka / Streaming
   ↓
CI/CD Data
   ↓
Security
   ↓
Advanced Data Engineering
   ↓
🚀 Final Data Engineering Project
```

## 📍 Position actuelle

**Module actuel : PostgreSQL Performance**

Déjà acquis :

> EXPLAIN → Seq Scan → Index Scan → Bitmap Scan → EXPLAIN ANALYZE → Buffers → Selectivity → pg_stats → ANALYZE

**Prochaine étape :**

> **Indexes avancés → Query Optimization → JOIN Plans**

Puis :

> **PySpark / Apache Spark** ⭐

---

## 🎯 Environnement cible

Pour l'apprentissage local :

```text
WSL Ubuntu
│
├── Python 3.14
├── PostgreSQL
├── dbt
├── Airflow
├── PySpark
├── Docker
├── Prometheus
└── Grafana
```

Avec **4 Go RAM / 256 Go SSD**, privilégier :

* Spark Local Mode
* petits volumes
* Olist comme dataset principal
* Parquet
* traitements optimisés
* peu de services Docker simultanément

Le passage au **Cloud / cluster distribué** viendra après la maîtrise des concepts locaux.
# Out:
#   Cell In[1], line 5
#     Construire une maîtrise complète du **Data Engineering moderne**, de la collecte des données jusqu'au traitement distribué, au cloud, au streaming et à la mise en production.
#                                                                                                       ^
# SyntaxError: unterminated string literal (detected at line 5)
