# %% [markdown]
# # Roadmap — Database Management / DBA
#
# ## 🎯 Objectif
#
# Maîtriser les compétences nécessaires pour **administrer, sécuriser, maintenir, superviser, optimiser et faire évoluer une base de données en production**.
#
# SGBD principal pour la pratique :
#
# > **PostgreSQL**
#
# ---
#
# # 1. Database Architecture ⭐⭐⭐
#
# Comprendre comment fonctionne réellement un SGBD.
#
# * [ ] Architecture Client / Server
# * [ ] Database
# * [ ] Schema
# * [ ] Tables
# * [ ] Indexes
# * [ ] Tablespaces
# * [ ] Data directory
# * [ ] PostgreSQL processes
# * [ ] Backend processes
# * [ ] Shared memory
# * [ ] Background processes
# * [ ] WAL
# * [ ] Checkpoints
# * [ ] Autovacuum
#
# ### PostgreSQL
#
# * [ ] `postgres`
# * [ ] `pg_ctl`
# * [ ] `pg_lsclusters`
# * [ ] `pg_isready`
# * [ ] Data directory
# * [ ] Configuration directory
#
# ---
#
# # 2. Installation & Configuration ⭐⭐⭐
#
# Savoir installer et configurer correctement un serveur.
#
# * [ ] Installation PostgreSQL
# * [ ] Initialisation d'un cluster
# * [ ] Gestion du service
# * [ ] Ports
# * [ ] `listen_addresses`
# * [ ] `postgresql.conf`
# * [ ] `pg_hba.conf`
# * [ ] `pg_ident.conf`
# * [ ] Configuration mémoire
# * [ ] Configuration réseau
# * [ ] Logging
# * [ ] Reload vs Restart
# * [ ] `SHOW`
# * [ ] `ALTER SYSTEM`
#
# ---
#
# # 3. Database & Schema Management ⭐⭐⭐
#
# * [ ] CREATE DATABASE
# * [ ] DROP DATABASE
# * [ ] Database ownership
# * [ ] CREATE SCHEMA
# * [ ] DROP SCHEMA
# * [ ] Schema ownership
# * [ ] `search_path`
# * [ ] Organisation des schemas
# * [ ] Séparation DEV / TEST / PROD
#
# ---
#
# # 4. Users, Roles & Permissions ⭐⭐⭐
#
# Un point fondamental pour un Database Manager.
#
# * [ ] Users vs Roles
# * [ ] CREATE ROLE
# * [ ] ALTER ROLE
# * [ ] DROP ROLE
# * [ ] LOGIN
# * [ ] SUPERUSER
# * [ ] Role inheritance
# * [ ] Group roles
# * [ ] `GRANT`
# * [ ] `REVOKE`
# * [ ] Database privileges
# * [ ] Schema privileges
# * [ ] Table privileges
# * [ ] Column privileges
# * [ ] Default privileges
# * [ ] Role hierarchy
# * [ ] Least Privilege
#
# ---
#
# # 5. Database Security ⭐⭐⭐
#
# * [ ] Authentication
# * [ ] Authorization
# * [ ] `pg_hba.conf`
# * [ ] `peer`
# * [ ] `scram-sha-256`
# * [ ] Password policies
# * [ ] SSL/TLS
# * [ ] Certificates
# * [ ] Encryption
# * [ ] Secrets management
# * [ ] Network security
# * [ ] Firewall concepts
# * [ ] Audit logging
# * [ ] Security hardening
# * [ ] Credential rotation
#
# ---
#
# # 6. Backup & Restore ⭐⭐⭐
#
# Une des responsabilités les plus importantes.
#
# ## Backup
#
# * [ ] `pg_dump`
# * [ ] `pg_dumpall`
# * [ ] Logical backup
# * [ ] Physical backup
# * [ ] Full backup
# * [ ] Schema-only
# * [ ] Data-only
# * [ ] Custom format
# * [ ] Backup retention
#
# ## Restore
#
# * [ ] `psql`
# * [ ] `pg_restore`
# * [ ] Full restore
# * [ ] Partial restore
# * [ ] Restore validation
#
# ## Stratégie
#
# * [ ] Backup frequency
# * [ ] Backup rotation
# * [ ] Backup storage
# * [ ] Backup encryption
# * [ ] Backup verification
# * [ ] Restore testing
#
# ---
#
# # 7. WAL & Recovery ⭐⭐⭐
#
# Comprendre comment PostgreSQL protège les données.
#
# * [ ] WAL
# * [ ] WAL segments
# * [ ] WAL buffers
# * [ ] WAL archiving
# * [ ] Checkpoints
# * [ ] Crash recovery
# * [ ] Recovery process
# * [ ] `wal_level`
# * [ ] `archive_mode`
# * [ ] `archive_command`
# * [ ] Point-in-Time Recovery
# * [ ] PITR
#
# ---
#
# # 8. Transactions & MVCC ⭐⭐⭐
#
# * [ ] ACID
# * [ ] BEGIN
# * [ ] COMMIT
# * [ ] ROLLBACK
# * [ ] SAVEPOINT
# * [ ] MVCC
# * [ ] Transaction IDs
# * [ ] Snapshots
# * [ ] Visibility
# * [ ] Long transactions
#
# ---
#
# # 9. Isolation & Concurrency ⭐⭐⭐
#
# * [ ] Read Committed
# * [ ] Repeatable Read
# * [ ] Serializable
# * [ ] Dirty Read
# * [ ] Non-repeatable Read
# * [ ] Phantom Read
# * [ ] Concurrent transactions
# * [ ] Serialization failures
#
# ---
#
# # 10. Locks & Deadlocks ⭐⭐⭐
#
# * [ ] Row locks
# * [ ] Table locks
# * [ ] `FOR UPDATE`
# * [ ] Blocking queries
# * [ ] Waiting transactions
# * [ ] Lock contention
# * [ ] Deadlocks
# * [ ] Deadlock detection
# * [ ] Troubleshooting blocked sessions
#
# ---
#
# # 11. Maintenance ⭐⭐⭐
#
# Maintenir la santé de la base.
#
# * [ ] VACUUM
# * [ ] VACUUM ANALYZE
# * [ ] VACUUM FULL
# * [ ] Autovacuum
# * [ ] Dead tuples
# * [ ] Table bloat
# * [ ] Index bloat
# * [ ] ANALYZE
# * [ ] REINDEX
# * [ ] Transaction ID wraparound
# * [ ] Maintenance scheduling
#
# ---
#
# # 12. Performance Management ⭐⭐⭐
#
# * [ ] EXPLAIN
# * [ ] EXPLAIN ANALYZE
# * [ ] Query Planner
# * [ ] Query Optimizer
# * [ ] Seq Scan
# * [ ] Index Scan
# * [ ] Bitmap Scan
# * [ ] Nested Loop
# * [ ] Hash Join
# * [ ] Merge Join
# * [ ] Selectivity
# * [ ] Statistics
# * [ ] Index design
# * [ ] Query optimization
# * [ ] `work_mem`
# * [ ] `shared_buffers`
# * [ ] `effective_cache_size`
# * [ ] Parallel queries
#
# > Cette partie rejoint directement ton module **PostgreSQL Performance** déjà commencé.
#
# ---
#
# # 13. Monitoring ⭐⭐⭐
#
# Savoir répondre à :
#
# > "Que se passe-t-il actuellement sur ma base ?"
#
# ## Sessions
#
# * [ ] `pg_stat_activity`
# * [ ] Active connections
# * [ ] Idle connections
# * [ ] Idle in transaction
# * [ ] Long-running queries
# * [ ] Waiting queries
#
# ## Database
#
# * [ ] `pg_stat_database`
# * [ ] Transactions
# * [ ] Commits
# * [ ] Rollbacks
# * [ ] Cache hit ratio
# * [ ] Database size
#
# ## Tables
#
# * [ ] `pg_stat_user_tables`
# * [ ] Sequential scans
# * [ ] Index scans
# * [ ] Dead tuples
# * [ ] Vacuum statistics
#
# ## Indexes
#
# * [ ] `pg_stat_user_indexes`
# * [ ] Index usage
# * [ ] Unused indexes
# * [ ] Index scans
#
# ---
#
# # 14. Logging & Troubleshooting ⭐⭐⭐
#
# * [ ] PostgreSQL logs
# * [ ] Log levels
# * [ ] Slow queries
# * [ ] Connection errors
# * [ ] Authentication errors
# * [ ] Lock errors
# * [ ] Deadlocks
# * [ ] Disk errors
# * [ ] Out of memory
# * [ ] Incident investigation
#
# ---
#
# # 15. Storage Management ⭐⭐
#
# * [ ] Disk usage
# * [ ] Database size
# * [ ] Table size
# * [ ] Index size
# * [ ] WAL size
# * [ ] Tablespaces
# * [ ] TOAST
# * [ ] Storage growth
# * [ ] Capacity planning
# * [ ] Disk alerts
#
# ---
#
# # 16. Partitioning ⭐⭐
#
# * [ ] Pourquoi partitionner ?
# * [ ] Range partitioning
# * [ ] List partitioning
# * [ ] Hash partitioning
# * [ ] Partitioned tables
# * [ ] Partition pruning
# * [ ] Partition indexes
# * [ ] Partition maintenance
#
# ---
#
# # 17. Replication ⭐⭐⭐
#
# ## Physical Replication
#
# * [ ] Primary
# * [ ] Standby
# * [ ] Streaming replication
# * [ ] WAL streaming
# * [ ] Replication slots
# * [ ] Replication lag
# * [ ] Synchronous replication
# * [ ] Asynchronous replication
#
# ## Logical Replication
#
# * [ ] Publication
# * [ ] Subscription
# * [ ] Logical replication
# * [ ] Use cases
# * [ ] Limitations
#
# ---
#
# # 18. High Availability ⭐⭐⭐
#
# * [ ] HA concepts
# * [ ] Primary / Standby
# * [ ] Failover
# * [ ] Switchover
# * [ ] Automatic failover
# * [ ] Connection routing
# * [ ] Load balancing
# * [ ] PgBouncer
# * [ ] HA monitoring
#
# ---
#
# # 19. Disaster Recovery ⭐⭐⭐
#
# * [ ] RPO
# * [ ] RTO
# * [ ] Backup strategy
# * [ ] PITR
# * [ ] WAL archiving
# * [ ] Failover
# * [ ] Recovery procedures
# * [ ] Disaster simulation
# * [ ] Recovery testing
# * [ ] Business Continuity
#
# ---
#
# # 20. Connection Management ⭐⭐
#
# * [ ] `max_connections`
# * [ ] Connection limits
# * [ ] Connection pooling
# * [ ] PgBouncer
# * [ ] Idle connections
# * [ ] Connection exhaustion
# * [ ] Application connection management
# * [ ] Connection monitoring
#
# ---
#
# # 21. Capacity Planning ⭐⭐
#
# Anticiper les problèmes avant qu'ils arrivent.
#
# * [ ] CPU usage
# * [ ] RAM usage
# * [ ] Disk usage
# * [ ] Connection growth
# * [ ] Table growth
# * [ ] Index growth
# * [ ] WAL growth
# * [ ] Query growth
# * [ ] Capacity forecasting
# * [ ] Scaling strategies
#
# ---
#
# # 22. Automation ⭐⭐
#
# * [ ] Bash
# * [ ] Python
# * [ ] Scheduled backups
# * [ ] Health checks
# * [ ] Maintenance scripts
# * [ ] Monitoring scripts
# * [ ] Automated alerts
# * [ ] Automated restore tests
# * [ ] Infrastructure as Code concepts
#
# ---
#
# # 23. Dev / Test / Production Management ⭐⭐
#
# * [ ] DEV database
# * [ ] TEST database
# * [ ] STAGING database
# * [ ] PROD database
# * [ ] Migration strategy
# * [ ] Schema versioning
# * [ ] Deployment strategy
# * [ ] Rollback strategy
# * [ ] Change management
# * [ ] Database release process
#
# ---
#
# # 24. Database Governance ⭐⭐
#
# Pour évoluer vers un rôle plus senior.
#
# * [ ] Data ownership
# * [ ] Data classification
# * [ ] Data retention
# * [ ] Data lifecycle
# * [ ] Access governance
# * [ ] Audit
# * [ ] Compliance concepts
# * [ ] Documentation
# * [ ] Data lineage
# * [ ] Operational procedures
#
# ---
#
# # 25. Database Tools
#
# ## PostgreSQL CLI
#
# * [ ] `psql`
# * [ ] `pg_ctl`
# * [ ] `pg_lsclusters`
# * [ ] `pg_isready`
# * [ ] `createdb`
# * [ ] `dropdb`
# * [ ] `createuser`
# * [ ] `pg_dump`
# * [ ] `pg_dumpall`
# * [ ] `pg_restore`
# * [ ] `pgbench`
#
# ## PostgreSQL Catalogs
#
# * [ ] `pg_catalog`
# * [ ] `pg_stat_*`
# * [ ] `pg_settings`
# * [ ] `pg_roles`
# * [ ] `pg_database`
# * [ ] `pg_tables`
# * [ ] `pg_indexes`
# * [ ] `information_schema`
#
# ---
#
# # 🚀 26. Projet final — Database Management
#
# Construire et administrer un environnement PostgreSQL réaliste.
#
# ```text
#                  APPLICATION
#                       │
#                       ▼
#                 ┌───────────┐
#                 │ PgBouncer │
#                 └─────┬─────┘
#                       │
#                       ▼
#              ┌─────────────────┐
#              │ PostgreSQL      │
#              │ PRIMARY         │
#              └───────┬─────────┘
#                      │
#              WAL / Replication
#                      │
#             ┌────────┴────────┐
#             ▼                 ▼
#       ┌───────────┐     ┌────────────┐
#       │  STANDBY  │     │   BACKUP   │
#       │ PostgreSQL│     │   Storage  │
#       └───────────┘     └────────────┘
#             │
#             ▼
#      ┌───────────────┐
#      │  Monitoring   │
#      │ Prometheus    │
#      │ Grafana       │
#      └───────────────┘
# ```
#
# ### Scénarios à savoir résoudre
#
# * [ ] PostgreSQL ne démarre plus
# * [ ] Disque presque plein
# * [ ] Trop de connexions
# * [ ] Query très lente
# * [ ] Deadlock
# * [ ] Transaction bloquée
# * [ ] Table avec beaucoup de dead tuples
# * [ ] Index inutilisé
# * [ ] Autovacuum problématique
# * [ ] Replication lag
# * [ ] Backup échoué
# * [ ] Restore complet
# * [ ] Point-in-Time Recovery
# * [ ] Failover
# * [ ] Incident de production
#
# ---
#
# # 🧭 Ordre recommandé
#
# ```text
# 1. Architecture
#        ↓
# 2. Installation / Configuration
#        ↓
# 3. Database / Schema
#        ↓
# 4. Users / Roles / Permissions
#        ↓
# 5. Security
#        ↓
# 6. Backup / Restore
#        ↓
# 7. WAL / Recovery
#        ↓
# 8. Transactions / MVCC
#        ↓
# 9. Concurrency
#        ↓
# 10. Locks / Deadlocks
#        ↓
# 11. Maintenance
#        ↓
# 12. Monitoring
#        ↓
# 13. Troubleshooting
#        ↓
# 14. Performance
#        ↓
# 15. Storage
#        ↓
# 16. Partitioning
#        ↓
# 17. Replication
#        ↓
# 18. High Availability
#        ↓
# 19. Disaster Recovery
#        ↓
# 20. Connection Management
#        ↓
# 21. Capacity Planning
#        ↓
# 22. Automation
#        ↓
# 23. Production Management
#        ↓
# 24. Governance
#        ↓
# 🚀 Projet final
# ```
#
# ---
#
# # 🎯 Les compétences prioritaires
#
# Si l'objectif est de devenir réellement opérationnel rapidement, les blocs à maîtriser en priorité sont :
#
# ```text
# ⭐⭐⭐ Architecture
# ⭐⭐⭐ Configuration
# ⭐⭐⭐ Roles / Permissions
# ⭐⭐⭐ Security
# ⭐⭐⭐ Backup / Restore
# ⭐⭐⭐ WAL / Recovery
# ⭐⭐⭐ Transactions
# ⭐⭐⭐ Locks
# ⭐⭐⭐ Maintenance
# ⭐⭐⭐ Monitoring
# ⭐⭐⭐ Troubleshooting
# ⭐⭐⭐ Performance
# ⭐⭐⭐ Replication
# ⭐⭐⭐ High Availability
# ⭐⭐⭐ Disaster Recovery
# ```
#
# Les sujets comme **Capacity Planning, Governance, IaC et architectures avancées** viennent ensuite.
#
# ---
#
# # 🔗 Retour vers le parcours Data Engineering
#
# Après Database Management :
#
# ```text
# Database Management
#         ↓
# PostgreSQL Performance
#         ↓
# PySpark / Spark
#         ↓
# Cloud Data Engineering
#         ↓
# Kafka / Streaming
#         ↓
# CI/CD Data
#         ↓
# Advanced Data Engineering
#         ↓
# 🚀 Final Data Engineering Project
# ```
#
# L'objectif est donc de faire de PostgreSQL une **base solide de Database Management**, puis de réutiliser cette connaissance dans ton parcours **Data Engineering**.
